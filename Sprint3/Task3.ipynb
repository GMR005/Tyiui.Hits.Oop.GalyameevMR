// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 6

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [ваш текст]
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) и реализуйте простое, сложное и множественное наследование

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public interface IWatchable
{
    void Watch(int views, string format);
}

public interface ICommentable
{
    void AddComment(string comment);
}

public class Movie
{
    private string _title;
    private string _director;
    private int _year;
    private double _rating;
    private string _genre;

    public Movie(string title, string director, int year, double rating, string genre)
    {
        this.Title = title;
        this.Director = director;
        this.Year = year;
        this.Rating = rating;
        this.Genre = genre;
    }

    public string Title
    {
        get { return _title; }
        set { _title = value; }
    }

    public string Director
    {
        get { return _director; }
        set { _director = value; }
    }

    public int Year
    {
        get { return _year; }
        set { _year = value; }
    }

   public double Rating
   {
       get { return _rating; }
       set
       {
           if (value >= 0)
           {
               _rating = Math.Round(value, 2); 
           }
           else
           {
               throw new ArgumentOutOfRangeException("Рейтинг не может быть отрицательным!");
           }
       }
   }
public void AddComment(string comment)
    {
        Console.WriteLine($"Добавлен комментарий к фильму: {comment}");
    }

     public void AddComment(string comment, string userName)
     {
         Console.WriteLine($"Добавлен комментарий к фильму от {userName}: {comment}");
     }
   public string Genre 
   {
       get { return _genre; }
       set { _genre = value; }
   }

   public virtual void Watch(int views, string format)
   {
       Console.WriteLine($"Просмотр: {Title}, Количество просмотров: {views}, Формат: {format}");
   }

   public virtual string GetInfo()
   {
       return $"Название: {Title}, Режиссер: {Director}, Год: {Year}, Рейтинг: {Rating}, Жанр: {Genre}.";
   }
}

public class AnimatedMovie : Movie, IWatchable, ICommentable
{
    private string studio;

    public AnimatedMovie(string title, string director, int year, double rating, string genre, string studio) 
      : base(title, director, year, rating, genre)
    {
        this.studio = studio;
    }

    public override void Watch(int views, string format)
    {
        Console.WriteLine($"Просмотр мультфильма: {Title}, Количество просмотров: {views}, Формат: {format}");
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Студия: {studio}."; 
    }

    public void AddComment(string comment)
    {
        Console.WriteLine($"Добавлен комментарий к мультфильму: {comment}");
    }

     public void AddComment(string comment, string userName)
     {
         Console.WriteLine($"Добавлен комментарий к мультфильму от {userName}: {comment}");
     }
}


public class Music
{
    private string _title;
    private string _artist;
    private int _year;

    public Music(string title, string artist, int year)
    {
        this.Title = title;
        this.Artist = artist;
        this.Year = year;
    }

    public string Title
    {
        get => _title;
        set => _title = value;
    }

    public string Artist
    {
        get => _artist;
        set => _artist = value;
    }

    public int Year
    {
        get => _year;
        set => _year = value;
    }

    public virtual string GetInfo()
    {
        return $"Музыка: {Title}, Исполнитель: {Artist}, Год: {Year}.";
    }
}


public class Song : Music
{
   private double duration;

   public Song(string title, string artist, int year, double duration) 
      : base(title, artist, year)
   {
       this.duration = duration;
   }

   public override string GetInfo()
   {
       return base.GetInfo() + $" Длительность: {duration} минут.";
   }
}


public class GenericCollection
{
     private List<object> items = new List<object>();

     public void AddItem(object item)
     {
         items.Add(item);
         Console.WriteLine($"Объект добавлен в коллекцию.");
     }

     public void ShowAllItems()
     {
         foreach (var item in items)
         {
             if (item is Movie movie) 
             {
                 Console.WriteLine(movie.GetInfo());
             }
             else if (item is Music music) 
             {
                 Console.WriteLine(music.GetInfo());
             }
             else 
             {
                 Console.WriteLine($"Объект типа: {item.GetType().Name}");
             }
         }
     }
}


var collection = new GenericCollection();


collection.AddItem(new Movie("Властелин колец", "Питер Джексон", 2001, 9.0142,"Фэнтези"));
collection.AddItem(new AnimatedMovie("История игрушек", "Джон Лассетер", 1995, 8.5,"Анимация", "Pixar"));
collection.AddItem(new Song("Bohemian Rhapsody", "Queen", 1975, 5.55));
collection.AddItem(new Song("Imagine", "John Lennon", 1971, 3.1));
Console.WriteLine("");
collection.ShowAllItems();
Console.WriteLine("");
Movie movie = new AnimatedMovie("Аркейн", "Паскаль Шаррю", 2021, 8.5, "Анимация", "Fortiche");
Console.WriteLine(movies.GetInfo());
movie.AddComment("Плохо");
movie.AddComment("Шикарно!", "Иван");


Console.ReadLine();
// Out:
// Объект добавлен в коллекцию.
// Объект добавлен в коллекцию.
// Объект добавлен в коллекцию.
// Объект добавлен в коллекцию.
//
// Название: Властелин колец, Режиссер: Питер Джексон, Год: 2001, Рейтинг: 9.01, Жанр: Фэнтези.
// Название: История игрушек, Режиссер: Джон Лассетер, Год: 1995, Рейтинг: 8.5, Жанр: Анимация., Студия: Pixar.
// Музыка: Bohemian Rhapsody, Исполнитель: Queen, Год: 1975. Длительность: 5.55 минут.
// Музыка: Imagine, Исполнитель: John Lennon, Год: 1971. Длительность: 3.1 минут.
//
// Название: Аркейн, Режиссер: Паскаль Шаррю, Год: 2021, Рейтинг: 8.5, Жанр: Анимация., Студия: Fortiche.
// Добавлен комментарий к фильму: Плохо
// Добавлен комментарий к фильму от Иван: Шикарно!
